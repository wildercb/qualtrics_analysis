# %% [markdown]
# #### Imports

# %%
from globals import *
from utils import *

import os
import re
import json
import pandas as pd
from collections import defaultdict

survey_df = pd.read_csv(survey_data)
annotations_dir = os.path.join(data_dir,'annotations')

# %% [markdown]
# ##### Rank questions (where the answers are stored in one column) responses by demographic

# %%
# Pick a question and demographic
question_col = "B.13.2"

demographics = ["Location","Role","Company Type","Dev Experience","Education", "Company Size", "Gender"]

demographic_key = "Location"

results = rank_question_answers_by_demographic(df=survey_df, question_col=question_col, demographic_key=demographic_key,
special_phrases=SPECIAL_PHRASES)

grouped_by_demo = results["grouped_by_demo"]
grouped_by_answer = results["grouped_by_answer"]

# Structured print
print("=== Ranking of answers BY DEMOGRAPHIC ===")
for group, answer_list in grouped_by_demo.items():
    print(f"\nDemographic Group: {group}")
    for ans, c, pct in answer_list:
        print(f"  {ans}: {c} mentions ({pct:.2f}%)")

print("\n=== Ranking of demographics BY ANSWER ===")
for ans, group_list in grouped_by_answer.items():
    print(f"\nAnswer: {ans}")
    for group, c, pct in group_list:
        print(f"  {group}: {c} mentions ({pct:.2f}%)")

# %% [markdown]
# ### Functions to View Our Annotation Data

# %%
####################################################
# Generate theme and code distributions
# Search for texts associated with themes / codes 
####################################################

os.chdir(data_dir)

input_json_path =  'annotations/json/B_Definitions.json'   
print("=== Report by Question ===")
# Generates textual report, set output_graph = True to generate graph in figures/annotations
generate_annotator_report(input_json_path, output_graph=False)


input_json_path =  'annotations/json/A_Definitions.json'  
print("=== Report by Question ===")
generate_annotator_report(input_json_path, output_graph=False)

''' 
# Search for texts of a specific theme or code.
tag_query = "pns"  # Replace with your theme or code of interest
results = search_annotations_texts_by_tag(input_json_path, tag_query)

print(f"\n=== Responses with tag '{tag_query}' ===")
if results:
    for q_code, text in results:
        print(f"Question {q_code}: {text}")
else:
    print("No responses found with that tag.")
'''

# Rank annotations themes by Demographic 
results_b = analyze_demographic_themes('annotations/json/B_Definitions.json', 'Role', 'ai_study_finalized.csv')
# results_a = analyze_demographic_themes('json/A_Definitions.json', 'Role', '../ai_study_finalized.csv')

# The above results are also json that can be saved 
# print(json.dumps(results, indent=4))
# Out:
# === Report by Question ===
# Question: B.1.1: How do you define AI within your industry? Briefly explain in your own words.
# Total responses: 243
# Responses with no theme (Other): 43 (17.70%)
# Themes:
#   - Theme: Process Automation: 78 responses (32.10%)
#   - Theme: Performance Improvement: 34 responses (13.99%)
#   - Theme: Content Synthesis: 33 responses (13.58%)
#   - Theme: Content Creation: 25 responses (10.29%)
#   - Theme: ML/DL: 19 responses (7.82%)
#   - Theme: Decision Making: 19 responses (7.82%)
#   - Theme: Recommendation: 14 responses (5.76%)
#   - Theme: Prediction: 13 responses (5.35%)
#   - Theme: Digital Assistance: 12 responses (4.94%)
#   - Theme: Personalization: 11 responses (4.53%)
#   - Theme: Detection: 8 responses (3.29%)
#   - Theme: Image analysis: 6 responses (2.47%)
#   - Theme: Vehicular Automation: 4 responses (1.65%)
#   - Theme: Information Retrieval: 4 responses (1.65%)
#   - Theme: Robotic Automation: 3 responses (1.23%)
# Codes:
#   - Code: Coding: 5 responses (2.06%)
#   - Code: Example response: 1 responses (0.41%)
# ----------------------------------------
# === Report by Question ===
# Question: A.1.1: How do you define AI within your industry? Briefly explain in your own words.
# Total responses: 106
# Responses with no theme (Other): 12 (11.32%)
# Themes:
#   - Theme: Process automation: 26 responses (24.53%)
#   - Theme: Performance improvement: 22 responses (20.75%)
#   - Theme: Content Creation: 22 responses (20.75%)
#   - Theme: ML/DL: 11 responses (10.38%)
#   - Theme: Content Synthesis: 9 responses (8.49%)
#   - Theme: Decision Making: 8 responses (7.55%)
#   - Theme: Digital Assistance: 8 responses (7.55%)
#   - Theme: Recommendation: 7 responses (6.60%)
#   - Theme: Prediction: 7 responses (6.60%)
#   - Theme: Information retrieval: 5 responses (4.72%)
#   - Theme: Monitoring: 3 responses (2.83%)
#   - Theme: Image analysis: 3 responses (2.83%)
#   - Theme: Personalization: 2 responses (1.89%)
#   - Theme: Detection: 1 responses (0.94%)
# Codes:
#   - Code: Coding: 9 responses (8.49%)
# ----------------------------------------
# === Aggregated Distribution of Themes by Demographic ===
# Role - AI developers: Total Responses = 118
#   Theme: Process Automation at 33.05% (Count: 39)
#   Theme: Content Synthesis at 13.56% (Count: 16)
#   Theme: Performance Improvement at 11.86% (Count: 14)
#   Theme: Digital Assistance at 7.63% (Count: 9)
#   Theme: Content Creation at 7.63% (Count: 9)
#   Theme: ML/DL at 7.63% (Count: 9)
#   Theme: Decision Making at 6.78% (Count: 8)
#   Theme: Recommendation at 6.78% (Count: 8)
#   Theme: Prediction at 5.08% (Count: 6)
#   Theme: Personalization at 3.39% (Count: 4)
#   Theme: Image analysis at 2.54% (Count: 3)
#   Theme: Detection at 2.54% (Count: 3)
#   Theme: Information Retrieval at 0.85% (Count: 1)
#   Theme: Vehicular Automation at 0.85% (Count: 1)
#
# Role - AI Manager: Total Responses = 39
#   Theme: Process Automation at 41.03% (Count: 16)
#   Theme: Performance Improvement at 15.38% (Count: 6)
#   Theme: Content Creation at 12.82% (Count: 5)
#   Theme: Content Synthesis at 10.26% (Count: 4)
#   Theme: Personalization at 7.69% (Count: 3)
#   Theme: Recommendation at 7.69% (Count: 3)
#   Theme: Prediction at 5.13% (Count: 2)
#   Theme: Detection at 2.56% (Count: 1)
#   Theme: Robotic Automation at 2.56% (Count: 1)
#   Theme: Vehicular Automation at 2.56% (Count: 1)
#   Theme: Digital Assistance at 2.56% (Count: 1)
#
# Role - Other: Total Responses = 13
#   Theme: Process Automation at 38.46% (Count: 5)
#   Theme: Performance Improvement at 30.77% (Count: 4)
#   Theme: Content Synthesis at 23.08% (Count: 3)
#   Theme: Decision Making at 23.08% (Count: 3)
#   Theme: Personalization at 15.38% (Count: 2)
#   Theme: Prediction at 7.69% (Count: 1)
#   Theme: Vehicular Automation at 7.69% (Count: 1)
#   Theme: ML/DL at 7.69% (Count: 1)
#   Theme: Content Creation at 7.69% (Count: 1)
#
# Role - Security/Privacy: Total Responses = 15
#   Theme: Content Creation at 33.33% (Count: 5)
#   Theme: Process Automation at 20.0% (Count: 3)
#   Theme: Detection at 13.33% (Count: 2)
#   Theme: ML/DL at 13.33% (Count: 2)
#   Theme: Content Synthesis at 13.33% (Count: 2)
#   Theme: Digital Assistance at 13.33% (Count: 2)
#   Theme: Performance Improvement at 13.33% (Count: 2)
#   Theme: Prediction at 6.67% (Count: 1)
#   Theme: Decision Making at 6.67% (Count: 1)
#   Theme: Recommendation at 6.67% (Count: 1)
#   Theme: Information Retrieval at 6.67% (Count: 1)
#
# Role - AI Researcher, AI Ethicist: Total Responses = 11
#   Theme: ML/DL at 18.18% (Count: 2)
#   Theme: Process Automation at 18.18% (Count: 2)
#   Theme: Performance Improvement at 18.18% (Count: 2)
#   Theme: Content Creation at 9.09% (Count: 1)
#   Theme: Content Synthesis at 9.09% (Count: 1)
#   Theme: Information Retrieval at 9.09% (Count: 1)
#   Theme: Decision Making at 9.09% (Count: 1)
#
# Role - QA and Maintenance: Total Responses = 18
#   Theme: Process Automation at 33.33% (Count: 6)
#   Theme: Decision Making at 27.78% (Count: 5)
#   Theme: Content Synthesis at 22.22% (Count: 4)
#   Theme: ML/DL at 16.67% (Count: 3)
#   Theme: Performance Improvement at 11.11% (Count: 2)
#   Theme: Prediction at 11.11% (Count: 2)
#   Theme: Content Creation at 11.11% (Count: 2)
#   Theme: Detection at 5.56% (Count: 1)
#   Theme: Personalization at 5.56% (Count: 1)
#   Theme: Image analysis at 5.56% (Count: 1)
#   Theme: Recommendation at 5.56% (Count: 1)
#   Theme: Robotic Automation at 5.56% (Count: 1)
#
# Role - Requirements analyst: Total Responses = 28
#   Theme: Process Automation at 25.0% (Count: 7)
#   Theme: Performance Improvement at 14.29% (Count: 4)
#   Theme: Content Synthesis at 10.71% (Count: 3)
#   Theme: Content Creation at 7.14% (Count: 2)
#   Theme: Image analysis at 7.14% (Count: 2)
#   Theme: Detection at 3.57% (Count: 1)
#   Theme: Personalization at 3.57% (Count: 1)
#   Theme: Prediction at 3.57% (Count: 1)
#   Theme: Recommendation at 3.57% (Count: 1)
#   Theme: Decision Making at 3.57% (Count: 1)
#   Theme: ML/DL at 3.57% (Count: 1)
#   Theme: Robotic Automation at 3.57% (Count: 1)
#   Theme: Vehicular Automation at 3.57% (Count: 1)
#   Theme: Information Retrieval at 3.57% (Count: 1)
#
# Role - : Total Responses = 1
#   Theme: ML/DL at 100.0% (Count: 1)
#
#
# === Ranking of Roles by Theme ===
#
# Process Automation:
#   Role: AI Manager at 41.03% (Count: 16)
#   Role: Other at 38.46% (Count: 5)
#   Role: QA and Maintenance at 33.33% (Count: 6)
#   Role: AI developers at 33.05% (Count: 39)
#   Role: Requirements analyst at 25.0% (Count: 7)
#   Role: Security/Privacy at 20.0% (Count: 3)
#   Role: AI Researcher, AI Ethicist at 18.18% (Count: 2)
#
# Content Synthesis:
#   Role: Other at 23.08% (Count: 3)
#   Role: QA and Maintenance at 22.22% (Count: 4)
#   Role: AI developers at 13.56% (Count: 16)
#   Role: Security/Privacy at 13.33% (Count: 2)
#   Role: Requirements analyst at 10.71% (Count: 3)
#   Role: AI Manager at 10.26% (Count: 4)
#   Role: AI Researcher, AI Ethicist at 9.09% (Count: 1)
#
# Performance Improvement:
#   Role: Other at 30.77% (Count: 4)
#   Role: AI Researcher, AI Ethicist at 18.18% (Count: 2)
#   Role: AI Manager at 15.38% (Count: 6)
#   Role: Requirements analyst at 14.29% (Count: 4)
#   Role: Security/Privacy at 13.33% (Count: 2)
#   Role: AI developers at 11.86% (Count: 14)
#   Role: QA and Maintenance at 11.11% (Count: 2)
#
# Digital Assistance:
#   Role: Security/Privacy at 13.33% (Count: 2)
#   Role: AI developers at 7.63% (Count: 9)
#   Role: AI Manager at 2.56% (Count: 1)
#
# Content Creation:
#   Role: Security/Privacy at 33.33% (Count: 5)
#   Role: AI Manager at 12.82% (Count: 5)
#   Role: QA and Maintenance at 11.11% (Count: 2)
#   Role: AI Researcher, AI Ethicist at 9.09% (Count: 1)
#   Role: Other at 7.69% (Count: 1)
#   Role: AI developers at 7.63% (Count: 9)
#   Role: Requirements analyst at 7.14% (Count: 2)
#
# ML/DL:
#   Role:  at 100.0% (Count: 1)
#   Role: AI Researcher, AI Ethicist at 18.18% (Count: 2)
#   Role: QA and Maintenance at 16.67% (Count: 3)
#   Role: Security/Privacy at 13.33% (Count: 2)
#   Role: Other at 7.69% (Count: 1)
#   Role: AI developers at 7.63% (Count: 9)
#   Role: Requirements analyst at 3.57% (Count: 1)
#
# Decision Making:
#   Role: QA and Maintenance at 27.78% (Count: 5)
#   Role: Other at 23.08% (Count: 3)
#   Role: AI Researcher, AI Ethicist at 9.09% (Count: 1)
#   Role: AI developers at 6.78% (Count: 8)
#   Role: Security/Privacy at 6.67% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#
# Recommendation:
#   Role: AI Manager at 7.69% (Count: 3)
#   Role: AI developers at 6.78% (Count: 8)
#   Role: Security/Privacy at 6.67% (Count: 1)
#   Role: QA and Maintenance at 5.56% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#
# Prediction:
#   Role: QA and Maintenance at 11.11% (Count: 2)
#   Role: Other at 7.69% (Count: 1)
#   Role: Security/Privacy at 6.67% (Count: 1)
#   Role: AI Manager at 5.13% (Count: 2)
#   Role: AI developers at 5.08% (Count: 6)
#   Role: Requirements analyst at 3.57% (Count: 1)
#
# Personalization:
#   Role: Other at 15.38% (Count: 2)
#   Role: AI Manager at 7.69% (Count: 3)
#   Role: QA and Maintenance at 5.56% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#   Role: AI developers at 3.39% (Count: 4)
#
# Image analysis:
#   Role: Requirements analyst at 7.14% (Count: 2)
#   Role: QA and Maintenance at 5.56% (Count: 1)
#   Role: AI developers at 2.54% (Count: 3)
#
# Detection:
#   Role: Security/Privacy at 13.33% (Count: 2)
#   Role: QA and Maintenance at 5.56% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#   Role: AI Manager at 2.56% (Count: 1)
#   Role: AI developers at 2.54% (Count: 3)
#
# Information Retrieval:
#   Role: AI Researcher, AI Ethicist at 9.09% (Count: 1)
#   Role: Security/Privacy at 6.67% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#   Role: AI developers at 0.85% (Count: 1)
#
# Vehicular Automation:
#   Role: Other at 7.69% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#   Role: AI Manager at 2.56% (Count: 1)
#   Role: AI developers at 0.85% (Count: 1)
#
# Robotic Automation:
#   Role: QA and Maintenance at 5.56% (Count: 1)
#   Role: Requirements analyst at 3.57% (Count: 1)
#   Role: AI Manager at 2.56% (Count: 1)

# %% [markdown]
# ##### Print graph and text for distribution of themes and codes found by role and principle in the written responses regarding risks and mitigation methods for AI ethics principles.

# %%
# Create graph displaying the distribution of themes and codes across different roles responses to how they view and mitigate risks to each principle of ethical AI

os.chdir(annotations_dir)

create_principle_role_graph('json/B_Risk_Mitigation.json', role_names, principle_names)

print_role_principle_analysis('json/B_Risk_Mitigation.json')
